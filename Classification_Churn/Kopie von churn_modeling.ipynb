# %%
import pandas as pd
import numpy as np
from numpy.core.fromnumeric import mean

from sklearn.linear_model import LogisticRegressionCV
from sklearn.svm import SVC
from sklearn.ensemble import GradientBoostingClassifier

from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score

from sklearn.pipeline import make_pipeline
from sklearn.pipeline import Pipeline

from sklearn.preprocessing import StandardScaler

from sklearn import metrics

# %%
## Read dataset
d = pd.read_csv('churn_modeling.csv', index_col = 'RowNumber')
#d
#d.describe()

# %%
## Encoding 
#d.dtypes

# Encode Geography into three dummies 
d['Geography'].unique()
d['Spain'] = d['Geography'].apply(lambda x: 1 if x =='Spain' else 0)
d['France'] = d['Geography'].apply(lambda x: 1 if x =='France' else 0)
d['Germany'] = d['Geography'].apply(lambda x: 1 if x =='Germany' else 0)

# Encode Gender into numeric values for Female
d['Female'] = d['Gender'].apply(lambda x: 1 if x =='Female' else 0)

# %%
# Dropping all Object columns plus CustomerID as they are not needed for prediction or encoded
d=d.drop(columns=['Geography', 'Gender', 'Surname', 'CustomerId'])
#d

# %%
# Feature transformation of Balance and Estimated Salary
# Checking for Null Values # None-There
d.isnull().sum()

# Transforming Balance and Estimated Salary to a logarithm
d = d.loc[d['Balance'] > 0]
d = d.loc[d['EstimatedSalary'] > 0]
d['EstimatedSalary'] = d['EstimatedSalary'].apply(lambda x: np.log(x))
d['Balance'] = d['Balance'].apply(lambda x: np.log(x))
d
# Out:
#            CreditScore  Age  Tenure    Balance  ...  Spain  France  Germany  Female
# RowNumber                                       ...
# 2                  608   41       1  11.336282  ...      1       0        0       1
# 3                  502   42       8  11.980807  ...      0       1        0       1
# 5                  850   43       2  11.740147  ...      1       0        0       1
# 6                  645   44       8  11.641809  ...      1       0        0       0
# 8                  376   29       4  11.653094  ...      0       0        1       1
# ...                ...  ...     ...        ...  ...    ...     ...      ...     ...
# 9992               597   53       4  11.389415  ...      0       1        0       1
# 9994               644   28       7  11.951570  ...      0       1        0       0
# 9997               516   35      10  10.957270  ...      0       1        0       0
# 9999               772   42       3  11.226247  ...      0       0        1       0
# 10000              792   28       4  11.776388  ...      0       1        0       1
#
# [6383 rows x 13 columns]

# %%
# Dataset balancing for 'Exited'

## See whether dataset needs to be rebalanced in regards to exit rates
#data_log['Exited'].hist()
exit = d[d['Exited'] == 1]
no_exit = d[d['Exited'] == 0]
print(len(exit)/(len(exit)+len(no_exit))) # Only 25% Exited

## Balancing the data (for both data sets logarithmic and normal)
exit_index = exit.index
np.random.seed(86) #Random seed to reproduce results
random_exit_indexes = np.random.choice(exit_index, len(no_exit))
balanced_data = no_exit.append(d.loc[random_exit_indexes])

## Test whether the rebalancing worked
#exit = balanced_data[balanced_data['Exited'] == 1]
#no_exit = balanced_data[balanced_data['Exited'] == 0]
print(len(exit)/(len(exit)+len(no_exit))) #Now 50% Exited
#balanced_data['Exited'].hist()
# Out:
# 0.2407958640137866
# 0.2407958640137866

# %%
## Test-Training Dataset

Y = balanced_data['Exited']
X = balanced_data.drop(['Exited'], axis=1)
X_train, X_test, y_train, y_test = train_test_split(X, Y, random_state=17)

# %%
## Logistic Regression not tuned
logres = LogisticRegressionCV(scoring='roc_auc', 
                              max_iter = 500)
logres.fit(X_train, y_train)
logres_model_scores = cross_val_score(logres, X_test, y_test, cv=5, scoring='roc_auc') 


print('The average roc_auc is {0} from the {1}-folded cross-validated Logistic Regression'.format(str(round(mean(logres_model_scores), 4)), str(5)))
# Out:
# The average roc_auc is 0.7443 from the 5-folded cross-validated Logistic Regression

# %%
### SVC Model not tuned
svc_model = make_pipeline(StandardScaler(), SVC())
svc_model.fit(X_train, y_train)
svc_model_scores = cross_val_score(svc_model, X_test,y_test, cv=5, scoring='roc_auc')
print('From the not tuned SVC StandardScaler the average roc_auc is {0}'.format(str(round(mean(svc_model_scores),3))))
# Out:
# From the not tuned SVC StandardScaler the average roc_auc is 0.832

# %%
### SVC Model tuned woth GridSearch
# Parameters that should be tuned
tuned_parameter = {'svc__C': [0.1,1,10], #The larger the C the higher the penalty for miskaes, suggested [0.1:100]
                   'svc__gamma': [0.0001, 0.001, 0.01, 0.1, 1], #The larger the gamma the more overfitted, default 1/n_feature, suggested [0.001:10]
                   'svc__degree': [1,2,3], #Degree of function
                   'svc__kernel': ['rbf','linear']} #Kernel used (poly scored low and takes long, so excluded)

## Constructing the Pipeline
gs_scv_model = GridSearchCV(svc_model,
                      param_grid=tuned_parameter,
                      scoring='roc_auc',
                      refit = 'AUC',
                      cv = 5)

#Fitting and testing the model
#gs_scv_model=gs_scv_model.fit(X_train, y_train)
gs_scv_model_scores = cross_val_score(gs_scv_model, X_test, y_test, scoring='roc_auc', cv=5)

print('From the tuned SVC StandardScaler the average roc_auc is {0}'.format(str(round(mean(gs_scv_model_scores),3))))
# Out:
# Fitting 3 folds for each of 90 candidates, totalling 270 fits
# [CV 1/3] END svc__C=0.1, svc__degree=1, svc__gamma=0.0001, svc__kernel=rbf;, score=0.718 total time=   0.2s
# [CV 2/3] END svc__C=0.1, svc__degree=1, svc__gamma=0.0001, svc__kernel=rbf;, score=0.746 total time=   0.2s
# [CV 3/3] END svc__C=0.1, svc__degree=1, svc__gamma=0.0001, svc__kernel=rbf;, score=0.732 total time=   0.2s
# [CV 1/3] END svc__C=0.1, svc__degree=1, svc__gamma=0.0001, svc__kernel=linear;, score=0.733 total time=   0.1s
# [CV 2/3] END svc__C=0.1, svc__degree=1, svc__gamma=0.0001, svc__kernel=linear;, score=0.761 total time=   0.1s
# [CV 3/3] END svc__C=0.1, svc__degree=1, svc__gamma=0.0001, svc__kernel=linear;, score=0.733 total time=   0.1s
# [CV 1/3] END svc__C=0.1, svc__degree=1, svc__gamma=0.001, svc__kernel=rbf;, score=0.719 total time=   0.2s
# [CV 2/3] END svc__C=0.1, svc__degree=1, svc__gamma=0.001, svc__kernel=rbf;, score=0.746 total time=   0.2s
# [CV 3/3] END svc__C=0.1, svc__degree=1, svc__gamma=0.001, svc__kernel=rbf;, score=0.732 total time=   0.2s
# [CV 1/3] END svc__C=0.1, svc__degree=1, svc__gamma=0.001, svc__kernel=linear;, score=0.733 total time=   0.1s
# [CV 2/3] END svc__C=0.1, svc__degree=1, svc__gamma=0.001, svc__kernel=linear;, score=0.761 total time=   0.1s
# [CV 3/3] END svc__C=0.1, svc__degree=1, svc__gamma=0.001, svc__kernel=linear;, score=0.733 total time=   0.1s
# [CV 1/3] END svc__C=0.1, svc__degree=1, svc__gamma=0.01, svc__kernel=rbf;, score=0.732 total time=   0.2s
# [CV 2/3] END svc__C=0.1, svc__degree=1, svc__gamma=0.01, svc__kernel=rbf;, score=0.757 total time=   0.2s
# [CV 3/3] END svc__C=0.1, svc__degree=1, svc__gamma=0.01, svc__kernel=rbf;, score=0.740 total time=   0.2s
# [CV 1/3] END svc__C=0.1, svc__degree=1, svc__gamma=0.01, svc__kernel=linear;, score=0.733 total time=   0.1s
# [CV 2/3] END svc__C=0.1, svc__degree=1, svc__gamma=0.01, svc__kernel=linear;, score=0.761 total time=   0.1s
# [CV 3/3] END svc__C=0.1, svc__degree=1, svc__gamma=0.01, svc__kernel=linear;, score=0.733 total time=   0.1s
# [CV 1/3] END svc__C=0.1, svc__degree=1, svc__gamma=0.1, svc__kernel=rbf;, score=0.774 total time=   0.2s
# [CV 2/3] END svc__C=0.1, svc__degree=1, svc__gamma=0.1, svc__kernel=rbf;, score=0.794 total time=   0.2s
# [CV 3/3] END svc__C=0.1, svc__degree=1, svc__gamma=0.1, svc__kernel=rbf;, score=0.787 total time=   0.2s
# [CV 1/3] END svc__C=0.1, svc__degree=1, svc__gamma=0.1, svc__kernel=linear;, score=0.733 total time=   0.1s
# [CV 2/3] END svc__C=0.1, svc__degree=1, svc__gamma=0.1, svc__kernel=linear;, score=0.761 total time=   0.1s
# [CV 3/3] END svc__C=0.1, svc__degree=1, svc__gamma=0.1, svc__kernel=linear;, score=0.733 total time=   0.1s
# [CV 1/3] END svc__C=0.1, svc__degree=1, svc__gamma=1, svc__kernel=rbf;, score=0.801 total time=   0.2s
# [CV 2/3] END svc__C=0.1, svc__degree=1, svc__gamma=1, svc__kernel=rbf;, score=0.788 total time=   0.2s
# [CV 3/3] END svc__C=0.1, svc__degree=1, svc__gamma=1, svc__kernel=rbf;, score=0.811 total time=   0.2s
# [CV 1/3] END svc__C=0.1, svc__degree=1, svc__gamma=1, svc__kernel=linear;, score=0.733 total time=   0.1s
# [CV 2/3] END svc__C=0.1, svc__degree=1, svc__gamma=1, svc__kernel=linear;, score=0.761 total time=   0.1s
# [CV 3/3] END svc__C=0.1, svc__degree=1, svc__gamma=1, svc__kernel=linear;, score=0.733 total time=   0.1s
# [CV 1/3] END svc__C=0.1, svc__degree=2, svc__gamma=0.0001, svc__kernel=rbf;, score=0.718 total time=   0.2s
# [CV 2/3] END svc__C=0.1, svc__degree=2, svc__gamma=0.0001, svc__kernel=rbf;, score=0.746 total time=   0.2s
# [CV 3/3] END svc__C=0.1, svc__degree=2, svc__gamma=0.0001, svc__kernel=rbf;, score=0.732 total time=   0.2s
# [CV 1/3] END svc__C=0.1, svc__degree=2, svc__gamma=0.0001, svc__kernel=linear;, score=0.733 total time=   0.1s
# [CV 2/3] END svc__C=0.1, svc__degree=2, svc__gamma=0.0001, svc__kernel=linear;, score=0.761 total time=   0.1s
# [CV 3/3] END svc__C=0.1, svc__degree=2, svc__gamma=0.0001, svc__kernel=linear;, score=0.733 total time=   0.1s
# [CV 1/3] END svc__C=0.1, svc__degree=2, svc__gamma=0.001, svc__kernel=rbf;, score=0.719 total time=   0.2s
# [CV 2/3] END svc__C=0.1, svc__degree=2, svc__gamma=0.001, svc__kernel=rbf;, score=0.746 total time=   0.2s
# [CV 3/3] END svc__C=0.1, svc__degree=2, svc__gamma=0.001, svc__kernel=rbf;, score=0.732 total time=   0.2s
# [CV 1/3] END svc__C=0.1, svc__degree=2, svc__gamma=0.001, svc__kernel=linear;, score=0.733 total time=   0.1s
# [CV 2/3] END svc__C=0.1, svc__degree=2, svc__gamma=0.001, svc__kernel=linear;, score=0.761 total time=   0.1s
# [CV 3/3] END svc__C=0.1, svc__degree=2, svc__gamma=0.001, svc__kernel=linear;, score=0.733 total time=   0.1s
# [CV 1/3] END svc__C=0.1, svc__degree=2, svc__gamma=0.01, svc__kernel=rbf;, score=0.732 total time=   0.2s
# [CV 2/3] END svc__C=0.1, svc__degree=2, svc__gamma=0.01, svc__kernel=rbf;, score=0.757 total time=   0.2s
# [CV 3/3] END svc__C=0.1, svc__degree=2, svc__gamma=0.01, svc__kernel=rbf;, score=0.740 total time=   0.2s
# [CV 1/3] END svc__C=0.1, svc__degree=2, svc__gamma=0.01, svc__kernel=linear;, score=0.733 total time=   0.1s
# [CV 2/3] END svc__C=0.1, svc__degree=2, svc__gamma=0.01, svc__kernel=linear;, score=0.761 total time=   0.1s
# [CV 3/3] END svc__C=0.1, svc__degree=2, svc__gamma=0.01, svc__kernel=linear;, score=0.733 total time=   0.1s
# [CV 1/3] END svc__C=0.1, svc__degree=2, svc__gamma=0.1, svc__kernel=rbf;, score=0.774 total time=   0.2s
# [CV 2/3] END svc__C=0.1, svc__degree=2, svc__gamma=0.1, svc__kernel=rbf;, score=0.794 total time=   0.2s
# [CV 3/3] END svc__C=0.1, svc__degree=2, svc__gamma=0.1, svc__kernel=rbf;, score=0.787 total time=   0.1s
# [CV 1/3] END svc__C=0.1, svc__degree=2, svc__gamma=0.1, svc__kernel=linear;, score=0.733 total time=   0.1s
# [CV 2/3] END svc__C=0.1, svc__degree=2, svc__gamma=0.1, svc__kernel=linear;, score=0.761 total time=   0.1s
# [CV 3/3] END svc__C=0.1, svc__degree=2, svc__gamma=0.1, svc__kernel=linear;, score=0.733 total time=   0.1s
# [CV 1/3] END svc__C=0.1, svc__degree=2, svc__gamma=1, svc__kernel=rbf;, score=0.801 total time=   0.2s
# [CV 2/3] END svc__C=0.1, svc__degree=2, svc__gamma=1, svc__kernel=rbf;, score=0.788 total time=   0.2s
# [CV 3/3] END svc__C=0.1, svc__degree=2, svc__gamma=1, svc__kernel=rbf;, score=0.811 total time=   0.2s
# [CV 1/3] END svc__C=0.1, svc__degree=2, svc__gamma=1, svc__kernel=linear;, score=0.733 total time=   0.1s
# [CV 2/3] END svc__C=0.1, svc__degree=2, svc__gamma=1, svc__kernel=linear;, score=0.761 total time=   0.1s
# [CV 3/3] END svc__C=0.1, svc__degree=2, svc__gamma=1, svc__kernel=linear;, score=0.733 total time=   0.1s
# [CV 1/3] END svc__C=0.1, svc__degree=3, svc__gamma=0.0001, svc__kernel=rbf;, score=0.718 total time=   0.2s
# [CV 2/3] END svc__C=0.1, svc__degree=3, svc__gamma=0.0001, svc__kernel=rbf;, score=0.746 total time=   0.2s
# [CV 3/3] END svc__C=0.1, svc__degree=3, svc__gamma=0.0001, svc__kernel=rbf;, score=0.732 total time=   0.2s
# [CV 1/3] END svc__C=0.1, svc__degree=3, svc__gamma=0.0001, svc__kernel=linear;, score=0.733 total time=   0.1s
# [CV 2/3] END svc__C=0.1, svc__degree=3, svc__gamma=0.0001, svc__kernel=linear;, score=0.761 total time=   0.1s
# [CV 3/3] END svc__C=0.1, svc__degree=3, svc__gamma=0.0001, svc__kernel=linear;, score=0.733 total time=   0.1s
# [CV 1/3] END svc__C=0.1, svc__degree=3, svc__gamma=0.001, svc__kernel=rbf;, score=0.719 total time=   0.2s
# [CV 2/3] END svc__C=0.1, svc__degree=3, svc__gamma=0.001, svc__kernel=rbf;, score=0.746 total time=   0.2s
# [CV 3/3] END svc__C=0.1, svc__degree=3, svc__gamma=0.001, svc__kernel=rbf;, score=0.732 total time=   0.2s
# [CV 1/3] END svc__C=0.1, svc__degree=3, svc__gamma=0.001, svc__kernel=linear;, score=0.733 total time=   0.1s
# [CV 2/3] END svc__C=0.1, svc__degree=3, svc__gamma=0.001, svc__kernel=linear;, score=0.761 total time=   0.1s
# [CV 3/3] END svc__C=0.1, svc__degree=3, svc__gamma=0.001, svc__kernel=linear;, score=0.733 total time=   0.1s
# [CV 1/3] END svc__C=0.1, svc__degree=3, svc__gamma=0.01, svc__kernel=rbf;, score=0.732 total time=   0.2s
# [CV 2/3] END svc__C=0.1, svc__degree=3, svc__gamma=0.01, svc__kernel=rbf;, score=0.757 total time=   0.2s
# [CV 3/3] END svc__C=0.1, svc__degree=3, svc__gamma=0.01, svc__kernel=rbf;, score=0.740 total time=   0.2s
# [CV 1/3] END svc__C=0.1, svc__degree=3, svc__gamma=0.01, svc__kernel=linear;, score=0.733 total time=   0.1s
# [CV 2/3] END svc__C=0.1, svc__degree=3, svc__gamma=0.01, svc__kernel=linear;, score=0.761 total time=   0.1s
# [CV 3/3] END svc__C=0.1, svc__degree=3, svc__gamma=0.01, svc__kernel=linear;, score=0.733 total time=   0.1s
# [CV 1/3] END svc__C=0.1, svc__degree=3, svc__gamma=0.1, svc__kernel=rbf;, score=0.774 total time=   0.2s
# [CV 2/3] END svc__C=0.1, svc__degree=3, svc__gamma=0.1, svc__kernel=rbf;, score=0.794 total time=   0.1s
# [CV 3/3] END svc__C=0.1, svc__degree=3, svc__gamma=0.1, svc__kernel=rbf;, score=0.787 total time=   0.2s
# [CV 1/3] END svc__C=0.1, svc__degree=3, svc__gamma=0.1, svc__kernel=linear;, score=0.733 total time=   0.1s
# [CV 2/3] END svc__C=0.1, svc__degree=3, svc__gamma=0.1, svc__kernel=linear;, score=0.761 total time=   0.1s
# [CV 3/3] END svc__C=0.1, svc__degree=3, svc__gamma=0.1, svc__kernel=linear;, score=0.733 total time=   0.1s
# [CV 1/3] END svc__C=0.1, svc__degree=3, svc__gamma=1, svc__kernel=rbf;, score=0.801 total time=   0.2s
# [CV 2/3] END svc__C=0.1, svc__degree=3, svc__gamma=1, svc__kernel=rbf;, score=0.788 total time=   0.2s
# [CV 3/3] END svc__C=0.1, svc__degree=3, svc__gamma=1, svc__kernel=rbf;, score=0.811 total time=   0.2s
# [CV 1/3] END svc__C=0.1, svc__degree=3, svc__gamma=1, svc__kernel=linear;, score=0.733 total time=   0.1s
# [CV 2/3] END svc__C=0.1, svc__degree=3, svc__gamma=1, svc__kernel=linear;, score=0.761 total time=   0.1s
# [CV 3/3] END svc__C=0.1, svc__degree=3, svc__gamma=1, svc__kernel=linear;, score=0.733 total time=   0.1s
# [CV 1/3] END svc__C=1, svc__degree=1, svc__gamma=0.0001, svc__kernel=rbf;, score=0.718 total time=   0.2s
# [CV 2/3] END svc__C=1, svc__degree=1, svc__gamma=0.0001, svc__kernel=rbf;, score=0.746 total time=   0.2s
# [CV 3/3] END svc__C=1, svc__degree=1, svc__gamma=0.0001, svc__kernel=rbf;, score=0.732 total time=   0.2s
# [CV 1/3] END svc__C=1, svc__degree=1, svc__gamma=0.0001, svc__kernel=linear;, score=0.733 total time=   0.1s
# [CV 2/3] END svc__C=1, svc__degree=1, svc__gamma=0.0001, svc__kernel=linear;, score=0.760 total time=   0.1s
# [CV 3/3] END svc__C=1, svc__degree=1, svc__gamma=0.0001, svc__kernel=linear;, score=0.733 total time=   0.1s
# [CV 1/3] END svc__C=1, svc__degree=1, svc__gamma=0.001, svc__kernel=rbf;, score=0.726 total time=   0.2s
# [CV 2/3] END svc__C=1, svc__degree=1, svc__gamma=0.001, svc__kernel=rbf;, score=0.755 total time=   0.2s
# [CV 3/3] END svc__C=1, svc__degree=1, svc__gamma=0.001, svc__kernel=rbf;, score=0.734 total time=   0.2s
# [CV 1/3] END svc__C=1, svc__degree=1, svc__gamma=0.001, svc__kernel=linear;, score=0.733 total time=   0.1s
# [CV 2/3] END svc__C=1, svc__degree=1, svc__gamma=0.001, svc__kernel=linear;, score=0.760 total time=   0.1s
# [CV 3/3] END svc__C=1, svc__degree=1, svc__gamma=0.001, svc__kernel=linear;, score=0.733 total time=   0.1s
# [CV 1/3] END svc__C=1, svc__degree=1, svc__gamma=0.01, svc__kernel=rbf;, score=0.759 total time=   0.1s
# [CV 2/3] END svc__C=1, svc__degree=1, svc__gamma=0.01, svc__kernel=rbf;, score=0.780 total time=   0.1s
# [CV 3/3] END svc__C=1, svc__degree=1, svc__gamma=0.01, svc__kernel=rbf;, score=0.758 total time=   0.1s
# [CV 1/3] END svc__C=1, svc__degree=1, svc__gamma=0.01, svc__kernel=linear;, score=0.733 total time=   0.1s
# [CV 2/3] END svc__C=1, svc__degree=1, svc__gamma=0.01, svc__kernel=linear;, score=0.760 total time=   0.1s
# [CV 3/3] END svc__C=1, svc__degree=1, svc__gamma=0.01, svc__kernel=linear;, score=0.733 total time=   0.1s
# [CV 1/3] END svc__C=1, svc__degree=1, svc__gamma=0.1, svc__kernel=rbf;, score=0.810 total time=   0.1s
# [CV 2/3] END svc__C=1, svc__degree=1, svc__gamma=0.1, svc__kernel=rbf;, score=0.819 total time=   0.1s
# [CV 3/3] END svc__C=1, svc__degree=1, svc__gamma=0.1, svc__kernel=rbf;, score=0.845 total time=   0.1s
# [CV 1/3] END svc__C=1, svc__degree=1, svc__gamma=0.1, svc__kernel=linear;, score=0.733 total time=   0.1s
# [CV 2/3] END svc__C=1, svc__degree=1, svc__gamma=0.1, svc__kernel=linear;, score=0.760 total time=   0.1s
# [CV 3/3] END svc__C=1, svc__degree=1, svc__gamma=0.1, svc__kernel=linear;, score=0.733 total time=   0.1s
# [CV 1/3] END svc__C=1, svc__degree=1, svc__gamma=1, svc__kernel=rbf;, score=0.809 total time=   0.2s
# [CV 2/3] END svc__C=1, svc__degree=1, svc__gamma=1, svc__kernel=rbf;, score=0.780 total time=   0.2s
# [CV 3/3] END svc__C=1, svc__degree=1, svc__gamma=1, svc__kernel=rbf;, score=0.811 total time=   0.2s
# [CV 1/3] END svc__C=1, svc__degree=1, svc__gamma=1, svc__kernel=linear;, score=0.733 total time=   0.1s
# [CV 2/3] END svc__C=1, svc__degree=1, svc__gamma=1, svc__kernel=linear;, score=0.760 total time=   0.1s
# [CV 3/3] END svc__C=1, svc__degree=1, svc__gamma=1, svc__kernel=linear;, score=0.733 total time=   0.1s
# [CV 1/3] END svc__C=1, svc__degree=2, svc__gamma=0.0001, svc__kernel=rbf;, score=0.718 total time=   0.2s
# [CV 2/3] END svc__C=1, svc__degree=2, svc__gamma=0.0001, svc__kernel=rbf;, score=0.746 total time=   0.2s
# [CV 3/3] END svc__C=1, svc__degree=2, svc__gamma=0.0001, svc__kernel=rbf;, score=0.732 total time=   0.2s
# [CV 1/3] END svc__C=1, svc__degree=2, svc__gamma=0.0001, svc__kernel=linear;, score=0.733 total time=   0.1s
# [CV 2/3] END svc__C=1, svc__degree=2, svc__gamma=0.0001, svc__kernel=linear;, score=0.760 total time=   0.1s
# [CV 3/3] END svc__C=1, svc__degree=2, svc__gamma=0.0001, svc__kernel=linear;, score=0.733 total time=   0.1s
# [CV 1/3] END svc__C=1, svc__degree=2, svc__gamma=0.001, svc__kernel=rbf;, score=0.726 total time=   0.2s
# [CV 2/3] END svc__C=1, svc__degree=2, svc__gamma=0.001, svc__kernel=rbf;, score=0.755 total time=   0.1s
# [CV 3/3] END svc__C=1, svc__degree=2, svc__gamma=0.001, svc__kernel=rbf;, score=0.734 total time=   0.2s
# [CV 1/3] END svc__C=1, svc__degree=2, svc__gamma=0.001, svc__kernel=linear;, score=0.733 total time=   0.1s
# [CV 2/3] END svc__C=1, svc__degree=2, svc__gamma=0.001, svc__kernel=linear;, score=0.760 total time=   0.1s
# [CV 3/3] END svc__C=1, svc__degree=2, svc__gamma=0.001, svc__kernel=linear;, score=0.733 total time=   0.1s
# [CV 1/3] END svc__C=1, svc__degree=2, svc__gamma=0.01, svc__kernel=rbf;, score=0.759 total time=   0.1s
# [CV 2/3] END svc__C=1, svc__degree=2, svc__gamma=0.01, svc__kernel=rbf;, score=0.780 total time=   0.1s
# [CV 3/3] END svc__C=1, svc__degree=2, svc__gamma=0.01, svc__kernel=rbf;, score=0.758 total time=   0.1s
# [CV 1/3] END svc__C=1, svc__degree=2, svc__gamma=0.01, svc__kernel=linear;, score=0.733 total time=   0.1s
# [CV 2/3] END svc__C=1, svc__degree=2, svc__gamma=0.01, svc__kernel=linear;, score=0.760 total time=   0.1s
# [CV 3/3] END svc__C=1, svc__degree=2, svc__gamma=0.01, svc__kernel=linear;, score=0.733 total time=   0.1s
# [CV 1/3] END svc__C=1, svc__degree=2, svc__gamma=0.1, svc__kernel=rbf;, score=0.810 total time=   0.1s
# [CV 2/3] END svc__C=1, svc__degree=2, svc__gamma=0.1, svc__kernel=rbf;, score=0.819 total time=   0.1s
# [CV 3/3] END svc__C=1, svc__degree=2, svc__gamma=0.1, svc__kernel=rbf;, score=0.845 total time=   0.1s
# [CV 1/3] END svc__C=1, svc__degree=2, svc__gamma=0.1, svc__kernel=linear;, score=0.733 total time=   0.1s
# [CV 2/3] END svc__C=1, svc__degree=2, svc__gamma=0.1, svc__kernel=linear;, score=0.760 total time=   0.1s
# [CV 3/3] END svc__C=1, svc__degree=2, svc__gamma=0.1, svc__kernel=linear;, score=0.733 total time=   0.1s
# [CV 1/3] END svc__C=1, svc__degree=2, svc__gamma=1, svc__kernel=rbf;, score=0.809 total time=   0.2s
# [CV 2/3] END svc__C=1, svc__degree=2, svc__gamma=1, svc__kernel=rbf;, score=0.780 total time=   0.2s
# [CV 3/3] END svc__C=1, svc__degree=2, svc__gamma=1, svc__kernel=rbf;, score=0.811 total time=   0.2s
# [CV 1/3] END svc__C=1, svc__degree=2, svc__gamma=1, svc__kernel=linear;, score=0.733 total time=   0.1s
# [CV 2/3] END svc__C=1, svc__degree=2, svc__gamma=1, svc__kernel=linear;, score=0.760 total time=   0.1s
# [CV 3/3] END svc__C=1, svc__degree=2, svc__gamma=1, svc__kernel=linear;, score=0.733 total time=   0.1s
# [CV 1/3] END svc__C=1, svc__degree=3, svc__gamma=0.0001, svc__kernel=rbf;, score=0.718 total time=   0.2s
# [CV 2/3] END svc__C=1, svc__degree=3, svc__gamma=0.0001, svc__kernel=rbf;, score=0.746 total time=   0.2s
# [CV 3/3] END svc__C=1, svc__degree=3, svc__gamma=0.0001, svc__kernel=rbf;, score=0.732 total time=   0.2s
# [CV 1/3] END svc__C=1, svc__degree=3, svc__gamma=0.0001, svc__kernel=linear;, score=0.733 total time=   0.1s
# [CV 2/3] END svc__C=1, svc__degree=3, svc__gamma=0.0001, svc__kernel=linear;, score=0.760 total time=   0.1s
# [CV 3/3] END svc__C=1, svc__degree=3, svc__gamma=0.0001, svc__kernel=linear;, score=0.733 total time=   0.1s
# [CV 1/3] END svc__C=1, svc__degree=3, svc__gamma=0.001, svc__kernel=rbf;, score=0.726 total time=   0.2s
# [CV 2/3] END svc__C=1, svc__degree=3, svc__gamma=0.001, svc__kernel=rbf;, score=0.755 total time=   0.2s
# [CV 3/3] END svc__C=1, svc__degree=3, svc__gamma=0.001, svc__kernel=rbf;, score=0.734 total time=   0.2s
# [CV 1/3] END svc__C=1, svc__degree=3, svc__gamma=0.001, svc__kernel=linear;, score=0.733 total time=   0.1s
# [CV 2/3] END svc__C=1, svc__degree=3, svc__gamma=0.001, svc__kernel=linear;, score=0.760 total time=   0.1s
# [CV 3/3] END svc__C=1, svc__degree=3, svc__gamma=0.001, svc__kernel=linear;, score=0.733 total time=   0.1s
# [CV 1/3] END svc__C=1, svc__degree=3, svc__gamma=0.01, svc__kernel=rbf;, score=0.759 total time=   0.1s
# [CV 2/3] END svc__C=1, svc__degree=3, svc__gamma=0.01, svc__kernel=rbf;, score=0.780 total time=   0.1s
# [CV 3/3] END svc__C=1, svc__degree=3, svc__gamma=0.01, svc__kernel=rbf;, score=0.758 total time=   0.1s
# [CV 1/3] END svc__C=1, svc__degree=3, svc__gamma=0.01, svc__kernel=linear;, score=0.733 total time=   0.1s
# [CV 2/3] END svc__C=1, svc__degree=3, svc__gamma=0.01, svc__kernel=linear;, score=0.760 total time=   0.1s
# [CV 3/3] END svc__C=1, svc__degree=3, svc__gamma=0.01, svc__kernel=linear;, score=0.733 total time=   0.1s
# [CV 1/3] END svc__C=1, svc__degree=3, svc__gamma=0.1, svc__kernel=rbf;, score=0.810 total time=   0.1s
# [CV 2/3] END svc__C=1, svc__degree=3, svc__gamma=0.1, svc__kernel=rbf;, score=0.819 total time=   0.1s
# [CV 3/3] END svc__C=1, svc__degree=3, svc__gamma=0.1, svc__kernel=rbf;, score=0.845 total time=   0.1s
# [CV 1/3] END svc__C=1, svc__degree=3, svc__gamma=0.1, svc__kernel=linear;, score=0.733 total time=   0.1s
# [CV 2/3] END svc__C=1, svc__degree=3, svc__gamma=0.1, svc__kernel=linear;, score=0.760 total time=   0.1s
# [CV 3/3] END svc__C=1, svc__degree=3, svc__gamma=0.1, svc__kernel=linear;, score=0.733 total time=   0.1s
# [CV 1/3] END svc__C=1, svc__degree=3, svc__gamma=1, svc__kernel=rbf;, score=0.809 total time=   0.2s
# [CV 2/3] END svc__C=1, svc__degree=3, svc__gamma=1, svc__kernel=rbf;, score=0.780 total time=   0.2s
# [CV 3/3] END svc__C=1, svc__degree=3, svc__gamma=1, svc__kernel=rbf;, score=0.811 total time=   0.2s
# [CV 1/3] END svc__C=1, svc__degree=3, svc__gamma=1, svc__kernel=linear;, score=0.733 total time=   0.1s
# [CV 2/3] END svc__C=1, svc__degree=3, svc__gamma=1, svc__kernel=linear;, score=0.760 total time=   0.1s
# [CV 3/3] END svc__C=1, svc__degree=3, svc__gamma=1, svc__kernel=linear;, score=0.733 total time=   0.1s
# [CV 1/3] END svc__C=10, svc__degree=1, svc__gamma=0.0001, svc__kernel=rbf;, score=0.726 total time=   0.2s
# [CV 2/3] END svc__C=10, svc__degree=1, svc__gamma=0.0001, svc__kernel=rbf;, score=0.755 total time=   0.2s
# [CV 3/3] END svc__C=10, svc__degree=1, svc__gamma=0.0001, svc__kernel=rbf;, score=0.733 total time=   0.2s
# [CV 1/3] END svc__C=10, svc__degree=1, svc__gamma=0.0001, svc__kernel=linear;, score=0.734 total time=   0.4s
# [CV 2/3] END svc__C=10, svc__degree=1, svc__gamma=0.0001, svc__kernel=linear;, score=0.761 total time=   0.3s
# [CV 3/3] END svc__C=10, svc__degree=1, svc__gamma=0.0001, svc__kernel=linear;, score=0.732 total time=   0.4s
# [CV 1/3] END svc__C=10, svc__degree=1, svc__gamma=0.001, svc__kernel=rbf;, score=0.739 total time=   0.1s
# [CV 2/3] END svc__C=10, svc__degree=1, svc__gamma=0.001, svc__kernel=rbf;, score=0.762 total time=   0.1s
# [CV 3/3] END svc__C=10, svc__degree=1, svc__gamma=0.001, svc__kernel=rbf;, score=0.738 total time=   0.1s
# [CV 1/3] END svc__C=10, svc__degree=1, svc__gamma=0.001, svc__kernel=linear;, score=0.734 total time=   0.4s
# [CV 2/3] END svc__C=10, svc__degree=1, svc__gamma=0.001, svc__kernel=linear;, score=0.761 total time=   0.3s
# [CV 3/3] END svc__C=10, svc__degree=1, svc__gamma=0.001, svc__kernel=linear;, score=0.732 total time=   0.3s
# [CV 1/3] END svc__C=10, svc__degree=1, svc__gamma=0.01, svc__kernel=rbf;, score=0.787 total time=   0.1s
# [CV 2/3] END svc__C=10, svc__degree=1, svc__gamma=0.01, svc__kernel=rbf;, score=0.805 total time=   0.1s
# [CV 3/3] END svc__C=10, svc__degree=1, svc__gamma=0.01, svc__kernel=rbf;, score=0.816 total time=   0.1s
# [CV 1/3] END svc__C=10, svc__degree=1, svc__gamma=0.01, svc__kernel=linear;, score=0.734 total time=   0.4s
# [CV 2/3] END svc__C=10, svc__degree=1, svc__gamma=0.01, svc__kernel=linear;, score=0.761 total time=   0.3s
# [CV 3/3] END svc__C=10, svc__degree=1, svc__gamma=0.01, svc__kernel=linear;, score=0.732 total time=   0.4s
# [CV 1/3] END svc__C=10, svc__degree=1, svc__gamma=0.1, svc__kernel=rbf;, score=0.804 total time=   0.1s
# [CV 2/3] END svc__C=10, svc__degree=1, svc__gamma=0.1, svc__kernel=rbf;, score=0.813 total time=   0.2s
# [CV 3/3] END svc__C=10, svc__degree=1, svc__gamma=0.1, svc__kernel=rbf;, score=0.838 total time=   0.1s
# [CV 1/3] END svc__C=10, svc__degree=1, svc__gamma=0.1, svc__kernel=linear;, score=0.734 total time=   0.4s
# [CV 2/3] END svc__C=10, svc__degree=1, svc__gamma=0.1, svc__kernel=linear;, score=0.761 total time=   0.4s
# [CV 3/3] END svc__C=10, svc__degree=1, svc__gamma=0.1, svc__kernel=linear;, score=0.732 total time=   0.3s
# [CV 1/3] END svc__C=10, svc__degree=1, svc__gamma=1, svc__kernel=rbf;, score=0.806 total time=   0.2s
# [CV 2/3] END svc__C=10, svc__degree=1, svc__gamma=1, svc__kernel=rbf;, score=0.763 total time=   0.2s
# [CV 3/3] END svc__C=10, svc__degree=1, svc__gamma=1, svc__kernel=rbf;, score=0.794 total time=   0.2s
# [CV 1/3] END svc__C=10, svc__degree=1, svc__gamma=1, svc__kernel=linear;, score=0.734 total time=   0.4s
# [CV 2/3] END svc__C=10, svc__degree=1, svc__gamma=1, svc__kernel=linear;, score=0.761 total time=   0.3s
# [CV 3/3] END svc__C=10, svc__degree=1, svc__gamma=1, svc__kernel=linear;, score=0.732 total time=   0.4s
# [CV 1/3] END svc__C=10, svc__degree=2, svc__gamma=0.0001, svc__kernel=rbf;, score=0.726 total time=   0.2s
# [CV 2/3] END svc__C=10, svc__degree=2, svc__gamma=0.0001, svc__kernel=rbf;, score=0.755 total time=   0.2s
# [CV 3/3] END svc__C=10, svc__degree=2, svc__gamma=0.0001, svc__kernel=rbf;, score=0.733 total time=   0.2s
# [CV 1/3] END svc__C=10, svc__degree=2, svc__gamma=0.0001, svc__kernel=linear;, score=0.734 total time=   0.4s
# [CV 2/3] END svc__C=10, svc__degree=2, svc__gamma=0.0001, svc__kernel=linear;, score=0.761 total time=   0.3s
# [CV 3/3] END svc__C=10, svc__degree=2, svc__gamma=0.0001, svc__kernel=linear;, score=0.732 total time=   0.3s
# [CV 1/3] END svc__C=10, svc__degree=2, svc__gamma=0.001, svc__kernel=rbf;, score=0.739 total time=   0.1s
# [CV 2/3] END svc__C=10, svc__degree=2, svc__gamma=0.001, svc__kernel=rbf;, score=0.762 total time=   0.1s
# [CV 3/3] END svc__C=10, svc__degree=2, svc__gamma=0.001, svc__kernel=rbf;, score=0.738 total time=   0.1s
# [CV 1/3] END svc__C=10, svc__degree=2, svc__gamma=0.001, svc__kernel=linear;, score=0.734 total time=   0.4s
# [CV 2/3] END svc__C=10, svc__degree=2, svc__gamma=0.001, svc__kernel=linear;, score=0.761 total time=   0.3s
# [CV 3/3] END svc__C=10, svc__degree=2, svc__gamma=0.001, svc__kernel=linear;, score=0.732 total time=   0.3s
# [CV 1/3] END svc__C=10, svc__degree=2, svc__gamma=0.01, svc__kernel=rbf;, score=0.787 total time=   0.1s
# [CV 2/3] END svc__C=10, svc__degree=2, svc__gamma=0.01, svc__kernel=rbf;, score=0.805 total time=   0.1s
# [CV 3/3] END svc__C=10, svc__degree=2, svc__gamma=0.01, svc__kernel=rbf;, score=0.816 total time=   0.1s
# [CV 1/3] END svc__C=10, svc__degree=2, svc__gamma=0.01, svc__kernel=linear;, score=0.734 total time=   0.4s
# [CV 2/3] END svc__C=10, svc__degree=2, svc__gamma=0.01, svc__kernel=linear;, score=0.761 total time=   0.4s
# [CV 3/3] END svc__C=10, svc__degree=2, svc__gamma=0.01, svc__kernel=linear;, score=0.732 total time=   0.3s
# [CV 1/3] END svc__C=10, svc__degree=2, svc__gamma=0.1, svc__kernel=rbf;, score=0.804 total time=   0.1s
# [CV 2/3] END svc__C=10, svc__degree=2, svc__gamma=0.1, svc__kernel=rbf;, score=0.813 total time=   0.1s
# [CV 3/3] END svc__C=10, svc__degree=2, svc__gamma=0.1, svc__kernel=rbf;, score=0.838 total time=   0.1s
# [CV 1/3] END svc__C=10, svc__degree=2, svc__gamma=0.1, svc__kernel=linear;, score=0.734 total time=   0.4s
# [CV 2/3] END svc__C=10, svc__degree=2, svc__gamma=0.1, svc__kernel=linear;, score=0.761 total time=   0.4s
# [CV 3/3] END svc__C=10, svc__degree=2, svc__gamma=0.1, svc__kernel=linear;, score=0.732 total time=   0.4s
# [CV 1/3] END svc__C=10, svc__degree=2, svc__gamma=1, svc__kernel=rbf;, score=0.806 total time=   0.2s
# [CV 2/3] END svc__C=10, svc__degree=2, svc__gamma=1, svc__kernel=rbf;, score=0.763 total time=   0.2s
# [CV 3/3] END svc__C=10, svc__degree=2, svc__gamma=1, svc__kernel=rbf;, score=0.794 total time=   0.2s
# [CV 1/3] END svc__C=10, svc__degree=2, svc__gamma=1, svc__kernel=linear;, score=0.734 total time=   0.4s
# [CV 2/3] END svc__C=10, svc__degree=2, svc__gamma=1, svc__kernel=linear;, score=0.761 total time=   0.4s
# [CV 3/3] END svc__C=10, svc__degree=2, svc__gamma=1, svc__kernel=linear;, score=0.732 total time=   0.4s
# [CV 1/3] END svc__C=10, svc__degree=3, svc__gamma=0.0001, svc__kernel=rbf;, score=0.726 total time=   0.2s
# [CV 2/3] END svc__C=10, svc__degree=3, svc__gamma=0.0001, svc__kernel=rbf;, score=0.755 total time=   0.2s
# [CV 3/3] END svc__C=10, svc__degree=3, svc__gamma=0.0001, svc__kernel=rbf;, score=0.733 total time=   0.2s
# [CV 1/3] END svc__C=10, svc__degree=3, svc__gamma=0.0001, svc__kernel=linear;, score=0.734 total time=   0.4s
# [CV 2/3] END svc__C=10, svc__degree=3, svc__gamma=0.0001, svc__kernel=linear;, score=0.761 total time=   0.4s
# [CV 3/3] END svc__C=10, svc__degree=3, svc__gamma=0.0001, svc__kernel=linear;, score=0.732 total time=   0.4s
# [CV 1/3] END svc__C=10, svc__degree=3, svc__gamma=0.001, svc__kernel=rbf;, score=0.739 total time=   0.1s
# [CV 2/3] END svc__C=10, svc__degree=3, svc__gamma=0.001, svc__kernel=rbf;, score=0.762 total time=   0.1s
# [CV 3/3] END svc__C=10, svc__degree=3, svc__gamma=0.001, svc__kernel=rbf;, score=0.738 total time=   0.1s
# [CV 1/3] END svc__C=10, svc__degree=3, svc__gamma=0.001, svc__kernel=linear;, score=0.734 total time=   0.4s
# [CV 2/3] END svc__C=10, svc__degree=3, svc__gamma=0.001, svc__kernel=linear;, score=0.761 total time=   0.3s
# [CV 3/3] END svc__C=10, svc__degree=3, svc__gamma=0.001, svc__kernel=linear;, score=0.732 total time=   0.3s
# [CV 1/3] END svc__C=10, svc__degree=3, svc__gamma=0.01, svc__kernel=rbf;, score=0.787 total time=   0.1s
# [CV 2/3] END svc__C=10, svc__degree=3, svc__gamma=0.01, svc__kernel=rbf;, score=0.805 total time=   0.1s
# [CV 3/3] END svc__C=10, svc__degree=3, svc__gamma=0.01, svc__kernel=rbf;, score=0.816 total time=   0.1s
# [CV 1/3] END svc__C=10, svc__degree=3, svc__gamma=0.01, svc__kernel=linear;, score=0.734 total time=   0.4s
# [CV 2/3] END svc__C=10, svc__degree=3, svc__gamma=0.01, svc__kernel=linear;, score=0.761 total time=   0.3s
# [CV 3/3] END svc__C=10, svc__degree=3, svc__gamma=0.01, svc__kernel=linear;, score=0.732 total time=   0.4s
# [CV 1/3] END svc__C=10, svc__degree=3, svc__gamma=0.1, svc__kernel=rbf;, score=0.804 total time=   0.1s
# [CV 2/3] END svc__C=10, svc__degree=3, svc__gamma=0.1, svc__kernel=rbf;, score=0.813 total time=   0.1s
# [CV 3/3] END svc__C=10, svc__degree=3, svc__gamma=0.1, svc__kernel=rbf;, score=0.838 total time=   0.1s
# [CV 1/3] END svc__C=10, svc__degree=3, svc__gamma=0.1, svc__kernel=linear;, score=0.734 total time=   0.4s
# [CV 2/3] END svc__C=10, svc__degree=3, svc__gamma=0.1, svc__kernel=linear;, score=0.761 total time=   0.3s
# [CV 3/3] END svc__C=10, svc__degree=3, svc__gamma=0.1, svc__kernel=linear;, score=0.732 total time=   0.3s
# [CV 1/3] END svc__C=10, svc__degree=3, svc__gamma=1, svc__kernel=rbf;, score=0.806 total time=   0.2s
# [CV 2/3] END svc__C=10, svc__degree=3, svc__gamma=1, svc__kernel=rbf;, score=0.763 total time=   0.2s
# [CV 3/3] END svc__C=10, svc__degree=3, svc__gamma=1, svc__kernel=rbf;, score=0.794 total time=   0.2s
# [CV 1/3] END svc__C=10, svc__degree=3, svc__gamma=1, svc__kernel=linear;, score=0.734 total time=   0.4s
# [CV 2/3] END svc__C=10, svc__degree=3, svc__gamma=1, svc__kernel=linear;, score=0.761 total time=   0.3s
# [CV 3/3] END svc__C=10, svc__degree=3, svc__gamma=1, svc__kernel=linear;, score=0.732 total time=   0.4s
# Fitting 3 folds for each of 90 candidates, totalling 270 fits
# [CV 1/3] END svc__C=0.1, svc__degree=1, svc__gamma=0.0001, svc__kernel=rbf;, score=0.732 total time=   0.2s
# [CV 2/3] END svc__C=0.1, svc__degree=1, svc__gamma=0.0001, svc__kernel=rbf;, score=0.738 total time=   0.2s
# [CV 3/3] END svc__C=0.1, svc__degree=1, svc__gamma=0.0001, svc__kernel=rbf;, score=0.733 total time=   0.2s
# [CV 1/3] END svc__C=0.1, svc__degree=1, svc__gamma=0.0001, svc__kernel=linear;, score=0.741 total time=   0.1s
# [CV 2/3] END svc__C=0.1, svc__degree=1, svc__gamma=0.0001, svc__kernel=linear;, score=0.752 total time=   0.1s
# [CV 3/3] END svc__C=0.1, svc__degree=1, svc__gamma=0.0001, svc__kernel=linear;, score=0.733 total time=   0.1s
# [CV 1/3] END svc__C=0.1, svc__degree=1, svc__gamma=0.001, svc__kernel=rbf;, score=0.732 total time=   0.2s
# [CV 2/3] END svc__C=0.1, svc__degree=1, svc__gamma=0.001, svc__kernel=rbf;, score=0.738 total time=   0.2s
# [CV 3/3] END svc__C=0.1, svc__degree=1, svc__gamma=0.001, svc__kernel=rbf;, score=0.734 total time=   0.2s
# [CV 1/3] END svc__C=0.1, svc__degree=1, svc__gamma=0.001, svc__kernel=linear;, score=0.741 total time=   0.1s
# [CV 2/3] END svc__C=0.1, svc__degree=1, svc__gamma=0.001, svc__kernel=linear;, score=0.752 total time=   0.1s
# [CV 3/3] END svc__C=0.1, svc__degree=1, svc__gamma=0.001, svc__kernel=linear;, score=0.733 total time=   0.1s
# [CV 1/3] END svc__C=0.1, svc__degree=1, svc__gamma=0.01, svc__kernel=rbf;, score=0.746 total time=   0.2s
# [CV 2/3] END svc__C=0.1, svc__degree=1, svc__gamma=0.01, svc__kernel=rbf;, score=0.748 total time=   0.2s
# [CV 3/3] END svc__C=0.1, svc__degree=1, svc__gamma=0.01, svc__kernel=rbf;, score=0.741 total time=   0.2s
# [CV 1/3] END svc__C=0.1, svc__degree=1, svc__gamma=0.01, svc__kernel=linear;, score=0.741 total time=   0.1s
# [CV 2/3] END svc__C=0.1, svc__degree=1, svc__gamma=0.01, svc__kernel=linear;, score=0.752 total time=   0.1s
# [CV 3/3] END svc__C=0.1, svc__degree=1, svc__gamma=0.01, svc__kernel=linear;, score=0.733 total time=   0.1s
# [CV 1/3] END svc__C=0.1, svc__degree=1, svc__gamma=0.1, svc__kernel=rbf;, score=0.777 total time=   0.2s
# [CV 2/3] END svc__C=0.1, svc__degree=1, svc__gamma=0.1, svc__kernel=rbf;, score=0.781 total time=   0.2s
# [CV 3/3] END svc__C=0.1, svc__degree=1, svc__gamma=0.1, svc__kernel=rbf;, score=0.791 total time=   0.2s
# [CV 1/3] END svc__C=0.1, svc__degree=1, svc__gamma=0.1, svc__kernel=linear;, score=0.741 total time=   0.1s
# [CV 2/3] END svc__C=0.1, svc__degree=1, svc__gamma=0.1, svc__kernel=linear;, score=0.752 total time=   0.1s
# [CV 3/3] END svc__C=0.1, svc__degree=1, svc__gamma=0.1, svc__kernel=linear;, score=0.733 total time=   0.1s
# [CV 1/3] END svc__C=0.1, svc__degree=1, svc__gamma=1, svc__kernel=rbf;, score=0.801 total time=   0.2s
# [CV 2/3] END svc__C=0.1, svc__degree=1, svc__gamma=1, svc__kernel=rbf;, score=0.806 total time=   0.2s
# [CV 3/3] END svc__C=0.1, svc__degree=1, svc__gamma=1, svc__kernel=rbf;, score=0.802 total time=   0.2s
# [CV 1/3] END svc__C=0.1, svc__degree=1, svc__gamma=1, svc__kernel=linear;, score=0.741 total time=   0.1s
# [CV 2/3] END svc__C=0.1, svc__degree=1, svc__gamma=1, svc__kernel=linear;, score=0.752 total time=   0.1s
# [CV 3/3] END svc__C=0.1, svc__degree=1, svc__gamma=1, svc__kernel=linear;, score=0.733 total time=   0.1s
# [CV 1/3] END svc__C=0.1, svc__degree=2, svc__gamma=0.0001, svc__kernel=rbf;, score=0.732 total time=   0.2s
# [CV 2/3] END svc__C=0.1, svc__degree=2, svc__gamma=0.0001, svc__kernel=rbf;, score=0.738 total time=   0.2s
# [CV 3/3] END svc__C=0.1, svc__degree=2, svc__gamma=0.0001, svc__kernel=rbf;, score=0.733 total time=   0.2s
# [CV 1/3] END svc__C=0.1, svc__degree=2, svc__gamma=0.0001, svc__kernel=linear;, score=0.741 total time=   0.1s
# [CV 2/3] END svc__C=0.1, svc__degree=2, svc__gamma=0.0001, svc__kernel=linear;, score=0.752 total time=   0.1s
# [CV 3/3] END svc__C=0.1, svc__degree=2, svc__gamma=0.0001, svc__kernel=linear;, score=0.733 total time=   0.1s
# [CV 1/3] END svc__C=0.1, svc__degree=2, svc__gamma=0.001, svc__kernel=rbf;, score=0.732 total time=   0.2s
# [CV 2/3] END svc__C=0.1, svc__degree=2, svc__gamma=0.001, svc__kernel=rbf;, score=0.738 total time=   0.2s
# [CV 3/3] END svc__C=0.1, svc__degree=2, svc__gamma=0.001, svc__kernel=rbf;, score=0.734 total time=   0.2s
# [CV 1/3] END svc__C=0.1, svc__degree=2, svc__gamma=0.001, svc__kernel=linear;, score=0.741 total time=   0.1s
# [CV 2/3] END svc__C=0.1, svc__degree=2, svc__gamma=0.001, svc__kernel=linear;, score=0.752 total time=   0.1s
# [CV 3/3] END svc__C=0.1, svc__degree=2, svc__gamma=0.001, svc__kernel=linear;, score=0.733 total time=   0.1s
# [CV 1/3] END svc__C=0.1, svc__degree=2, svc__gamma=0.01, svc__kernel=rbf;, score=0.746 total time=   0.2s
# [CV 2/3] END svc__C=0.1, svc__degree=2, svc__gamma=0.01, svc__kernel=rbf;, score=0.748 total time=   0.2s
# [CV 3/3] END svc__C=0.1, svc__degree=2, svc__gamma=0.01, svc__kernel=rbf;, score=0.741 total time=   0.2s
# [CV 1/3] END svc__C=0.1, svc__degree=2, svc__gamma=0.01, svc__kernel=linear;, score=0.741 total time=   0.1s
# [CV 2/3] END svc__C=0.1, svc__degree=2, svc__gamma=0.01, svc__kernel=linear;, score=0.752 total time=   0.1s
# [CV 3/3] END svc__C=0.1, svc__degree=2, svc__gamma=0.01, svc__kernel=linear;, score=0.733 total time=   0.1s
# [CV 1/3] END svc__C=0.1, svc__degree=2, svc__gamma=0.1, svc__kernel=rbf;, score=0.777 total time=   0.1s
# [CV 2/3] END svc__C=0.1, svc__degree=2, svc__gamma=0.1, svc__kernel=rbf;, score=0.781 total time=   0.1s
# [CV 3/3] END svc__C=0.1, svc__degree=2, svc__gamma=0.1, svc__kernel=rbf;, score=0.791 total time=   0.1s
# [CV 1/3] END svc__C=0.1, svc__degree=2, svc__gamma=0.1, svc__kernel=linear;, score=0.741 total time=   0.1s
# [CV 2/3] END svc__C=0.1, svc__degree=2, svc__gamma=0.1, svc__kernel=linear;, score=0.752 total time=   0.1s
# [CV 3/3] END svc__C=0.1, svc__degree=2, svc__gamma=0.1, svc__kernel=linear;, score=0.733 total time=   0.1s
# [CV 1/3] END svc__C=0.1, svc__degree=2, svc__gamma=1, svc__kernel=rbf;, score=0.801 total time=   0.2s
# [CV 2/3] END svc__C=0.1, svc__degree=2, svc__gamma=1, svc__kernel=rbf;, score=0.806 total time=   0.2s
# [CV 3/3] END svc__C=0.1, svc__degree=2, svc__gamma=1, svc__kernel=rbf;, score=0.802 total time=   0.2s
# [CV 1/3] END svc__C=0.1, svc__degree=2, svc__gamma=1, svc__kernel=linear;, score=0.741 total time=   0.1s
# [CV 2/3] END svc__C=0.1, svc__degree=2, svc__gamma=1, svc__kernel=linear;, score=0.752 total time=   0.1s
# [CV 3/3] END svc__C=0.1, svc__degree=2, svc__gamma=1, svc__kernel=linear;, score=0.733 total time=   0.1s
# [CV 1/3] END svc__C=0.1, svc__degree=3, svc__gamma=0.0001, svc__kernel=rbf;, score=0.732 total time=   0.2s
# [CV 2/3] END svc__C=0.1, svc__degree=3, svc__gamma=0.0001, svc__kernel=rbf;, score=0.738 total time=   0.2s
# [CV 3/3] END svc__C=0.1, svc__degree=3, svc__gamma=0.0001, svc__kernel=rbf;, score=0.733 total time=   0.2s
# [CV 1/3] END svc__C=0.1, svc__degree=3, svc__gamma=0.0001, svc__kernel=linear;, score=0.741 total time=   0.1s
# [CV 2/3] END svc__C=0.1, svc__degree=3, svc__gamma=0.0001, svc__kernel=linear;, score=0.752 total time=   0.1s
# [CV 3/3] END svc__C=0.1, svc__degree=3, svc__gamma=0.0001, svc__kernel=linear;, score=0.733 total time=   0.1s
# [CV 1/3] END svc__C=0.1, svc__degree=3, svc__gamma=0.001, svc__kernel=rbf;, score=0.732 total time=   0.2s
# [CV 2/3] END svc__C=0.1, svc__degree=3, svc__gamma=0.001, svc__kernel=rbf;, score=0.738 total time=   0.2s
# [CV 3/3] END svc__C=0.1, svc__degree=3, svc__gamma=0.001, svc__kernel=rbf;, score=0.734 total time=   0.2s
# [CV 1/3] END svc__C=0.1, svc__degree=3, svc__gamma=0.001, svc__kernel=linear;, score=0.741 total time=   0.1s
# [CV 2/3] END svc__C=0.1, svc__degree=3, svc__gamma=0.001, svc__kernel=linear;, score=0.752 total time=   0.1s
# [CV 3/3] END svc__C=0.1, svc__degree=3, svc__gamma=0.001, svc__kernel=linear;, score=0.733 total time=   0.1s
# [CV 1/3] END svc__C=0.1, svc__degree=3, svc__gamma=0.01, svc__kernel=rbf;, score=0.746 total time=   0.2s
# [CV 2/3] END svc__C=0.1, svc__degree=3, svc__gamma=0.01, svc__kernel=rbf;, score=0.748 total time=   0.2s
# [CV 3/3] END svc__C=0.1, svc__degree=3, svc__gamma=0.01, svc__kernel=rbf;, score=0.741 total time=   0.2s
# [CV 1/3] END svc__C=0.1, svc__degree=3, svc__gamma=0.01, svc__kernel=linear;, score=0.741 total time=   0.1s
# [CV 2/3] END svc__C=0.1, svc__degree=3, svc__gamma=0.01, svc__kernel=linear;, score=0.752 total time=   0.1s
# [CV 3/3] END svc__C=0.1, svc__degree=3, svc__gamma=0.01, svc__kernel=linear;, score=0.733 total time=   0.1s
# [CV 1/3] END svc__C=0.1, svc__degree=3, svc__gamma=0.1, svc__kernel=rbf;, score=0.777 total time=   0.2s
# [CV 2/3] END svc__C=0.1, svc__degree=3, svc__gamma=0.1, svc__kernel=rbf;, score=0.781 total time=   0.1s
# [CV 3/3] END svc__C=0.1, svc__degree=3, svc__gamma=0.1, svc__kernel=rbf;, score=0.791 total time=   0.2s
# [CV 1/3] END svc__C=0.1, svc__degree=3, svc__gamma=0.1, svc__kernel=linear;, score=0.741 total time=   0.1s
# [CV 2/3] END svc__C=0.1, svc__degree=3, svc__gamma=0.1, svc__kernel=linear;, score=0.752 total time=   0.1s
# [CV 3/3] END svc__C=0.1, svc__degree=3, svc__gamma=0.1, svc__kernel=linear;, score=0.733 total time=   0.1s
# [CV 1/3] END svc__C=0.1, svc__degree=3, svc__gamma=1, svc__kernel=rbf;, score=0.801 total time=   0.2s
# [CV 2/3] END svc__C=0.1, svc__degree=3, svc__gamma=1, svc__kernel=rbf;, score=0.806 total time=   0.2s
# [CV 3/3] END svc__C=0.1, svc__degree=3, svc__gamma=1, svc__kernel=rbf;, score=0.802 total time=   0.2s
# [CV 1/3] END svc__C=0.1, svc__degree=3, svc__gamma=1, svc__kernel=linear;, score=0.741 total time=   0.1s
# [CV 2/3] END svc__C=0.1, svc__degree=3, svc__gamma=1, svc__kernel=linear;, score=0.752 total time=   0.1s
# [CV 3/3] END svc__C=0.1, svc__degree=3, svc__gamma=1, svc__kernel=linear;, score=0.733 total time=   0.1s
# [CV 1/3] END svc__C=1, svc__degree=1, svc__gamma=0.0001, svc__kernel=rbf;, score=0.732 total time=   0.2s
# [CV 2/3] END svc__C=1, svc__degree=1, svc__gamma=0.0001, svc__kernel=rbf;, score=0.738 total time=   0.2s
# [CV 3/3] END svc__C=1, svc__degree=1, svc__gamma=0.0001, svc__kernel=rbf;, score=0.733 total time=   0.2s
# [CV 1/3] END svc__C=1, svc__degree=1, svc__gamma=0.0001, svc__kernel=linear;, score=0.740 total time=   0.1s
# [CV 2/3] END svc__C=1, svc__degree=1, svc__gamma=0.0001, svc__kernel=linear;, score=0.753 total time=   0.1s
# [CV 3/3] END svc__C=1, svc__degree=1, svc__gamma=0.0001, svc__kernel=linear;, score=0.733 total time=   0.1s
# [CV 1/3] END svc__C=1, svc__degree=1, svc__gamma=0.001, svc__kernel=rbf;, score=0.741 total time=   0.2s
# [CV 2/3] END svc__C=1, svc__degree=1, svc__gamma=0.001, svc__kernel=rbf;, score=0.746 total time=   0.2s
# [CV 3/3] END svc__C=1, svc__degree=1, svc__gamma=0.001, svc__kernel=rbf;, score=0.736 total time=   0.2s
# [CV 1/3] END svc__C=1, svc__degree=1, svc__gamma=0.001, svc__kernel=linear;, score=0.740 total time=   0.1s
# [CV 2/3] END svc__C=1, svc__degree=1, svc__gamma=0.001, svc__kernel=linear;, score=0.753 total time=   0.1s
# [CV 3/3] END svc__C=1, svc__degree=1, svc__gamma=0.001, svc__kernel=linear;, score=0.733 total time=   0.1s
# [CV 1/3] END svc__C=1, svc__degree=1, svc__gamma=0.01, svc__kernel=rbf;, score=0.769 total time=   0.1s
# [CV 2/3] END svc__C=1, svc__degree=1, svc__gamma=0.01, svc__kernel=rbf;, score=0.771 total time=   0.1s
# [CV 3/3] END svc__C=1, svc__degree=1, svc__gamma=0.01, svc__kernel=rbf;, score=0.764 total time=   0.1s
# [CV 1/3] END svc__C=1, svc__degree=1, svc__gamma=0.01, svc__kernel=linear;, score=0.740 total time=   0.1s
# [CV 2/3] END svc__C=1, svc__degree=1, svc__gamma=0.01, svc__kernel=linear;, score=0.753 total time=   0.1s
# [CV 3/3] END svc__C=1, svc__degree=1, svc__gamma=0.01, svc__kernel=linear;, score=0.733 total time=   0.1s
# [CV 1/3] END svc__C=1, svc__degree=1, svc__gamma=0.1, svc__kernel=rbf;, score=0.811 total time=   0.1s
# [CV 2/3] END svc__C=1, svc__degree=1, svc__gamma=0.1, svc__kernel=rbf;, score=0.813 total time=   0.1s
# [CV 3/3] END svc__C=1, svc__degree=1, svc__gamma=0.1, svc__kernel=rbf;, score=0.839 total time=   0.1s
# [CV 1/3] END svc__C=1, svc__degree=1, svc__gamma=0.1, svc__kernel=linear;, score=0.740 total time=   0.1s
# [CV 2/3] END svc__C=1, svc__degree=1, svc__gamma=0.1, svc__kernel=linear;, score=0.753 total time=   0.1s
# [CV 3/3] END svc__C=1, svc__degree=1, svc__gamma=0.1, svc__kernel=linear;, score=0.733 total time=   0.1s
# [CV 1/3] END svc__C=1, svc__degree=1, svc__gamma=1, svc__kernel=rbf;, score=0.813 total time=   0.2s
# [CV 2/3] END svc__C=1, svc__degree=1, svc__gamma=1, svc__kernel=rbf;, score=0.809 total time=   0.2s
# [CV 3/3] END svc__C=1, svc__degree=1, svc__gamma=1, svc__kernel=rbf;, score=0.799 total time=   0.2s
# [CV 1/3] END svc__C=1, svc__degree=1, svc__gamma=1, svc__kernel=linear;, score=0.740 total time=   0.1s
# [CV 2/3] END svc__C=1, svc__degree=1, svc__gamma=1, svc__kernel=linear;, score=0.753 total time=   0.1s
# [CV 3/3] END svc__C=1, svc__degree=1, svc__gamma=1, svc__kernel=linear;, score=0.733 total time=   0.1s
# [CV 1/3] END svc__C=1, svc__degree=2, svc__gamma=0.0001, svc__kernel=rbf;, score=0.732 total time=   0.2s
# [CV 2/3] END svc__C=1, svc__degree=2, svc__gamma=0.0001, svc__kernel=rbf;, score=0.738 total time=   0.2s
# [CV 3/3] END svc__C=1, svc__degree=2, svc__gamma=0.0001, svc__kernel=rbf;, score=0.733 total time=   0.2s
# [CV 1/3] END svc__C=1, svc__degree=2, svc__gamma=0.0001, svc__kernel=linear;, score=0.740 total time=   0.1s
# [CV 2/3] END svc__C=1, svc__degree=2, svc__gamma=0.0001, svc__kernel=linear;, score=0.753 total time=   0.1s
# [CV 3/3] END svc__C=1, svc__degree=2, svc__gamma=0.0001, svc__kernel=linear;, score=0.733 total time=   0.1s
# [CV 1/3] END svc__C=1, svc__degree=2, svc__gamma=0.001, svc__kernel=rbf;, score=0.741 total time=   0.2s
# [CV 2/3] END svc__C=1, svc__degree=2, svc__gamma=0.001, svc__kernel=rbf;, score=0.746 total time=   0.2s
# [CV 3/3] END svc__C=1, svc__degree=2, svc__gamma=0.001, svc__kernel=rbf;, score=0.736 total time=   0.2s
# [CV 1/3] END svc__C=1, svc__degree=2, svc__gamma=0.001, svc__kernel=linear;, score=0.740 total time=   0.1s
# [CV 2/3] END svc__C=1, svc__degree=2, svc__gamma=0.001, svc__kernel=linear;, score=0.753 total time=   0.1s
# [CV 3/3] END svc__C=1, svc__degree=2, svc__gamma=0.001, svc__kernel=linear;, score=0.733 total time=   0.1s
# [CV 1/3] END svc__C=1, svc__degree=2, svc__gamma=0.01, svc__kernel=rbf;, score=0.769 total time=   0.1s
# [CV 2/3] END svc__C=1, svc__degree=2, svc__gamma=0.01, svc__kernel=rbf;, score=0.771 total time=   0.1s
# [CV 3/3] END svc__C=1, svc__degree=2, svc__gamma=0.01, svc__kernel=rbf;, score=0.764 total time=   0.1s
# [CV 1/3] END svc__C=1, svc__degree=2, svc__gamma=0.01, svc__kernel=linear;, score=0.740 total time=   0.1s
# [CV 2/3] END svc__C=1, svc__degree=2, svc__gamma=0.01, svc__kernel=linear;, score=0.753 total time=   0.1s
# [CV 3/3] END svc__C=1, svc__degree=2, svc__gamma=0.01, svc__kernel=linear;, score=0.733 total time=   0.1s
# [CV 1/3] END svc__C=1, svc__degree=2, svc__gamma=0.1, svc__kernel=rbf;, score=0.811 total time=   0.1s
# [CV 2/3] END svc__C=1, svc__degree=2, svc__gamma=0.1, svc__kernel=rbf;, score=0.813 total time=   0.1s
# [CV 3/3] END svc__C=1, svc__degree=2, svc__gamma=0.1, svc__kernel=rbf;, score=0.839 total time=   0.1s
# [CV 1/3] END svc__C=1, svc__degree=2, svc__gamma=0.1, svc__kernel=linear;, score=0.740 total time=   0.1s
# [CV 2/3] END svc__C=1, svc__degree=2, svc__gamma=0.1, svc__kernel=linear;, score=0.753 total time=   0.1s
# [CV 3/3] END svc__C=1, svc__degree=2, svc__gamma=0.1, svc__kernel=linear;, score=0.733 total time=   0.1s
# [CV 1/3] END svc__C=1, svc__degree=2, svc__gamma=1, svc__kernel=rbf;, score=0.813 total time=   0.2s
# [CV 2/3] END svc__C=1, svc__degree=2, svc__gamma=1, svc__kernel=rbf;, score=0.809 total time=   0.2s
# [CV 3/3] END svc__C=1, svc__degree=2, svc__gamma=1, svc__kernel=rbf;, score=0.799 total time=   0.2s
# [CV 1/3] END svc__C=1, svc__degree=2, svc__gamma=1, svc__kernel=linear;, score=0.740 total time=   0.1s
# [CV 2/3] END svc__C=1, svc__degree=2, svc__gamma=1, svc__kernel=linear;, score=0.753 total time=   0.1s
# [CV 3/3] END svc__C=1, svc__degree=2, svc__gamma=1, svc__kernel=linear;, score=0.733 total time=   0.1s
# [CV 1/3] END svc__C=1, svc__degree=3, svc__gamma=0.0001, svc__kernel=rbf;, score=0.732 total time=   0.2s
# [CV 2/3] END svc__C=1, svc__degree=3, svc__gamma=0.0001, svc__kernel=rbf;, score=0.738 total time=   0.2s
# [CV 3/3] END svc__C=1, svc__degree=3, svc__gamma=0.0001, svc__kernel=rbf;, score=0.733 total time=   0.2s
# [CV 1/3] END svc__C=1, svc__degree=3, svc__gamma=0.0001, svc__kernel=linear;, score=0.740 total time=   0.1s
# [CV 2/3] END svc__C=1, svc__degree=3, svc__gamma=0.0001, svc__kernel=linear;, score=0.753 total time=   0.1s
# [CV 3/3] END svc__C=1, svc__degree=3, svc__gamma=0.0001, svc__kernel=linear;, score=0.733 total time=   0.1s
# [CV 1/3] END svc__C=1, svc__degree=3, svc__gamma=0.001, svc__kernel=rbf;, score=0.741 total time=   0.2s
# [CV 2/3] END svc__C=1, svc__degree=3, svc__gamma=0.001, svc__kernel=rbf;, score=0.746 total time=   0.2s
# [CV 3/3] END svc__C=1, svc__degree=3, svc__gamma=0.001, svc__kernel=rbf;, score=0.736 total time=   0.2s
# [CV 1/3] END svc__C=1, svc__degree=3, svc__gamma=0.001, svc__kernel=linear;, score=0.740 total time=   0.1s
# [CV 2/3] END svc__C=1, svc__degree=3, svc__gamma=0.001, svc__kernel=linear;, score=0.753 total time=   0.1s
# [CV 3/3] END svc__C=1, svc__degree=3, svc__gamma=0.001, svc__kernel=linear;, score=0.733 total time=   0.1s
# [CV 1/3] END svc__C=1, svc__degree=3, svc__gamma=0.01, svc__kernel=rbf;, score=0.769 total time=   0.1s
# [CV 2/3] END svc__C=1, svc__degree=3, svc__gamma=0.01, svc__kernel=rbf;, score=0.771 total time=   0.1s
# [CV 3/3] END svc__C=1, svc__degree=3, svc__gamma=0.01, svc__kernel=rbf;, score=0.764 total time=   0.1s
# [CV 1/3] END svc__C=1, svc__degree=3, svc__gamma=0.01, svc__kernel=linear;, score=0.740 total time=   0.1s
# [CV 2/3] END svc__C=1, svc__degree=3, svc__gamma=0.01, svc__kernel=linear;, score=0.753 total time=   0.1s
# [CV 3/3] END svc__C=1, svc__degree=3, svc__gamma=0.01, svc__kernel=linear;, score=0.733 total time=   0.1s
# [CV 1/3] END svc__C=1, svc__degree=3, svc__gamma=0.1, svc__kernel=rbf;, score=0.811 total time=   0.1s
# [CV 2/3] END svc__C=1, svc__degree=3, svc__gamma=0.1, svc__kernel=rbf;, score=0.813 total time=   0.1s
# [CV 3/3] END svc__C=1, svc__degree=3, svc__gamma=0.1, svc__kernel=rbf;, score=0.839 total time=   0.1s
# [CV 1/3] END svc__C=1, svc__degree=3, svc__gamma=0.1, svc__kernel=linear;, score=0.740 total time=   0.1s
# [CV 2/3] END svc__C=1, svc__degree=3, svc__gamma=0.1, svc__kernel=linear;, score=0.753 total time=   0.1s
# [CV 3/3] END svc__C=1, svc__degree=3, svc__gamma=0.1, svc__kernel=linear;, score=0.733 total time=   0.1s
# [CV 1/3] END svc__C=1, svc__degree=3, svc__gamma=1, svc__kernel=rbf;, score=0.813 total time=   0.2s
# [CV 2/3] END svc__C=1, svc__degree=3, svc__gamma=1, svc__kernel=rbf;, score=0.809 total time=   0.2s
# [CV 3/3] END svc__C=1, svc__degree=3, svc__gamma=1, svc__kernel=rbf;, score=0.799 total time=   0.2s
# [CV 1/3] END svc__C=1, svc__degree=3, svc__gamma=1, svc__kernel=linear;, score=0.740 total time=   0.1s
# [CV 2/3] END svc__C=1, svc__degree=3, svc__gamma=1, svc__kernel=linear;, score=0.753 total time=   0.1s
# [CV 3/3] END svc__C=1, svc__degree=3, svc__gamma=1, svc__kernel=linear;, score=0.733 total time=   0.1s
# ...
# [CV 1/3] END svc__C=1, svc__degree=2, svc__gamma=0.0001, svc__kernel=rbf;, score=0.744 total time=   0.2s
# [CV 2/3] END svc__C=1, svc__degree=2, svc__gamma=0.0001, svc__kernel=rbf;, score=0.727 total time=   0.2s
# [CV 3/3] END svc__C=1, svc__degree=2, svc__gamma=0.0001, svc__kernel=rbf;, score=0.731 total time=   0.2s
# [CV 1/3] END svc__C=1, svc__degree=2, svc__gamma=0.0001, svc__kernel=linear;, score=0.745 total time=   0.1s
# [CV 2/3] END svc__C=1, svc__degree=2, svc__gamma=0.0001, svc__kernel=linear;, score=0.747 total time=   0.1s
# [CV 3/3] END svc__C=1, svc__degree=2, svc__gamma=0.0001, svc__kernel=linear;, score=0.742 total time=   0.1s
# [CV 1/3] END svc__C=1, svc__degree=2, svc__gamma=0.001, svc__kernel=rbf;, score=0.747 total time=   0.2s
# [CV 2/3] END svc__C=1, svc__degree=2, svc__gamma=0.001, svc__kernel=rbf;, score=0.736 total time=   0.2s
# [CV 3/3] END svc__C=1, svc__degree=2, svc__gamma=0.001, svc__kernel=rbf;, score=0.740 total time=   0.2s
# [CV 1/3] END svc__C=1, svc__degree=2, svc__gamma=0.001, svc__kernel=linear;, score=0.745 total time=   0.1s
# [CV 2/3] END svc__C=1, svc__degree=2, svc__gamma=0.001, svc__kernel=linear;, score=0.747 total time=   0.1s
# [CV 3/3] END svc__C=1, svc__degree=2, svc__gamma=0.001, svc__kernel=linear;, score=0.742 total time=   0.1s
# [CV 1/3] END svc__C=1, svc__degree=2, svc__gamma=0.01, svc__kernel=rbf;, score=0.771 total time=   0.1s
# [CV 2/3] END svc__C=1, svc__degree=2, svc__gamma=0.01, svc__kernel=rbf;, score=0.765 total time=   0.2s
# [CV 3/3] END svc__C=1, svc__degree=2, svc__gamma=0.01, svc__kernel=rbf;, score=0.762 total time=   0.1s
# [CV 1/3] END svc__C=1, svc__degree=2, svc__gamma=0.01, svc__kernel=linear;, score=0.745 total time=   0.1s
# [CV 2/3] END svc__C=1, svc__degree=2, svc__gamma=0.01, svc__kernel=linear;, score=0.747 total time=   0.1s
# [CV 3/3] END svc__C=1, svc__degree=2, svc__gamma=0.01, svc__kernel=linear;, score=0.742 total time=   0.1s
# [CV 1/3] END svc__C=1, svc__degree=2, svc__gamma=0.1, svc__kernel=rbf;, score=0.826 total time=   0.1s
# [CV 2/3] END svc__C=1, svc__degree=2, svc__gamma=0.1, svc__kernel=rbf;, score=0.828 total time=   0.1s
# [CV 3/3] END svc__C=1, svc__degree=2, svc__gamma=0.1, svc__kernel=rbf;, score=0.818 total time=   0.1s
# [CV 1/3] END svc__C=1, svc__degree=2, svc__gamma=0.1, svc__kernel=linear;, score=0.745 total time=   0.1s
# [CV 2/3] END svc__C=1, svc__degree=2, svc__gamma=0.1, svc__kernel=linear;, score=0.747 total time=   0.1s
# [CV 3/3] END svc__C=1, svc__degree=2, svc__gamma=0.1, svc__kernel=linear;, score=0.742 total time=   0.1s
# [CV 1/3] END svc__C=1, svc__degree=2, svc__gamma=1, svc__kernel=rbf;, score=0.804 total time=   0.2s
# [CV 2/3] END svc__C=1, svc__degree=2, svc__gamma=1, svc__kernel=rbf;, score=0.817 total time=   0.2s
# [CV 3/3] END svc__C=1, svc__degree=2, svc__gamma=1, svc__kernel=rbf;, score=0.796 total time=   0.2s
# [CV 1/3] END svc__C=1, svc__degree=2, svc__gamma=1, svc__kernel=linear;, score=0.745 total time=   0.1s
# [CV 2/3] END svc__C=1, svc__degree=2, svc__gamma=1, svc__kernel=linear;, score=0.747 total time=   0.1s
# [CV 3/3] END svc__C=1, svc__degree=2, svc__gamma=1, svc__kernel=linear;, score=0.742 total time=   0.1s
# [CV 1/3] END svc__C=1, svc__degree=3, svc__gamma=0.0001, svc__kernel=rbf;, score=0.744 total time=   0.2s
# [CV 2/3] END svc__C=1, svc__degree=3, svc__gamma=0.0001, svc__kernel=rbf;, score=0.727 total time=   0.2s
# [CV 3/3] END svc__C=1, svc__degree=3, svc__gamma=0.0001, svc__kernel=rbf;, score=0.731 total time=   0.2s
# [CV 1/3] END svc__C=1, svc__degree=3, svc__gamma=0.0001, svc__kernel=linear;, score=0.745 total time=   0.1s
# [CV 2/3] END svc__C=1, svc__degree=3, svc__gamma=0.0001, svc__kernel=linear;, score=0.747 total time=   0.1s
# [CV 3/3] END svc__C=1, svc__degree=3, svc__gamma=0.0001, svc__kernel=linear;, score=0.742 total time=   0.1s
# [CV 1/3] END svc__C=1, svc__degree=3, svc__gamma=0.001, svc__kernel=rbf;, score=0.747 total time=   0.2s
# [CV 2/3] END svc__C=1, svc__degree=3, svc__gamma=0.001, svc__kernel=rbf;, score=0.736 total time=   0.1s
# [CV 3/3] END svc__C=1, svc__degree=3, svc__gamma=0.001, svc__kernel=rbf;, score=0.740 total time=   0.2s
# [CV 1/3] END svc__C=1, svc__degree=3, svc__gamma=0.001, svc__kernel=linear;, score=0.745 total time=   0.1s
# [CV 2/3] END svc__C=1, svc__degree=3, svc__gamma=0.001, svc__kernel=linear;, score=0.747 total time=   0.1s
# [CV 3/3] END svc__C=1, svc__degree=3, svc__gamma=0.001, svc__kernel=linear;, score=0.742 total time=   0.1s
# [CV 1/3] END svc__C=1, svc__degree=3, svc__gamma=0.01, svc__kernel=rbf;, score=0.771 total time=   0.1s
# [CV 2/3] END svc__C=1, svc__degree=3, svc__gamma=0.01, svc__kernel=rbf;, score=0.765 total time=   0.1s
# [CV 3/3] END svc__C=1, svc__degree=3, svc__gamma=0.01, svc__kernel=rbf;, score=0.762 total time=   0.1s
# [CV 1/3] END svc__C=1, svc__degree=3, svc__gamma=0.01, svc__kernel=linear;, score=0.745 total time=   0.1s
# [CV 2/3] END svc__C=1, svc__degree=3, svc__gamma=0.01, svc__kernel=linear;, score=0.747 total time=   0.1s
# [CV 3/3] END svc__C=1, svc__degree=3, svc__gamma=0.01, svc__kernel=linear;, score=0.742 total time=   0.1s
# [CV 1/3] END svc__C=1, svc__degree=3, svc__gamma=0.1, svc__kernel=rbf;, score=0.826 total time=   0.1s
# [CV 2/3] END svc__C=1, svc__degree=3, svc__gamma=0.1, svc__kernel=rbf;, score=0.828 total time=   0.1s
# [CV 3/3] END svc__C=1, svc__degree=3, svc__gamma=0.1, svc__kernel=rbf;, score=0.818 total time=   0.1s
# [CV 1/3] END svc__C=1, svc__degree=3, svc__gamma=0.1, svc__kernel=linear;, score=0.745 total time=   0.1s
# [CV 2/3] END svc__C=1, svc__degree=3, svc__gamma=0.1, svc__kernel=linear;, score=0.747 total time=   0.1s
# [CV 3/3] END svc__C=1, svc__degree=3, svc__gamma=0.1, svc__kernel=linear;, score=0.742 total time=   0.1s
# [CV 1/3] END svc__C=1, svc__degree=3, svc__gamma=1, svc__kernel=rbf;, score=0.804 total time=   0.2s
# [CV 2/3] END svc__C=1, svc__degree=3, svc__gamma=1, svc__kernel=rbf;, score=0.817 total time=   0.2s
# [CV 3/3] END svc__C=1, svc__degree=3, svc__gamma=1, svc__kernel=rbf;, score=0.796 total time=   0.2s
# [CV 1/3] END svc__C=1, svc__degree=3, svc__gamma=1, svc__kernel=linear;, score=0.745 total time=   0.1s
# [CV 2/3] END svc__C=1, svc__degree=3, svc__gamma=1, svc__kernel=linear;, score=0.747 total time=   0.1s
# [CV 3/3] END svc__C=1, svc__degree=3, svc__gamma=1, svc__kernel=linear;, score=0.742 total time=   0.1s
# [CV 1/3] END svc__C=10, svc__degree=1, svc__gamma=0.0001, svc__kernel=rbf;, score=0.746 total time=   0.2s
# [CV 2/3] END svc__C=10, svc__degree=1, svc__gamma=0.0001, svc__kernel=rbf;, score=0.735 total time=   0.2s
# [CV 3/3] END svc__C=10, svc__degree=1, svc__gamma=0.0001, svc__kernel=rbf;, score=0.740 total time=   0.2s
# [CV 1/3] END svc__C=10, svc__degree=1, svc__gamma=0.0001, svc__kernel=linear;, score=0.745 total time=   0.3s
# [CV 2/3] END svc__C=10, svc__degree=1, svc__gamma=0.0001, svc__kernel=linear;, score=0.747 total time=   0.3s
# [CV 3/3] END svc__C=10, svc__degree=1, svc__gamma=0.0001, svc__kernel=linear;, score=0.742 total time=   0.4s
# [CV 1/3] END svc__C=10, svc__degree=1, svc__gamma=0.001, svc__kernel=rbf;, score=0.752 total time=   0.1s
# [CV 2/3] END svc__C=10, svc__degree=1, svc__gamma=0.001, svc__kernel=rbf;, score=0.749 total time=   0.1s
# [CV 3/3] END svc__C=10, svc__degree=1, svc__gamma=0.001, svc__kernel=rbf;, score=0.746 total time=   0.1s
# [CV 1/3] END svc__C=10, svc__degree=1, svc__gamma=0.001, svc__kernel=linear;, score=0.745 total time=   0.3s
# [CV 2/3] END svc__C=10, svc__degree=1, svc__gamma=0.001, svc__kernel=linear;, score=0.747 total time=   0.3s
# [CV 3/3] END svc__C=10, svc__degree=1, svc__gamma=0.001, svc__kernel=linear;, score=0.742 total time=   0.4s
# [CV 1/3] END svc__C=10, svc__degree=1, svc__gamma=0.01, svc__kernel=rbf;, score=0.814 total time=   0.1s
# [CV 2/3] END svc__C=10, svc__degree=1, svc__gamma=0.01, svc__kernel=rbf;, score=0.797 total time=   0.1s
# [CV 3/3] END svc__C=10, svc__degree=1, svc__gamma=0.01, svc__kernel=rbf;, score=0.798 total time=   0.1s
# [CV 1/3] END svc__C=10, svc__degree=1, svc__gamma=0.01, svc__kernel=linear;, score=0.745 total time=   0.3s
# [CV 2/3] END svc__C=10, svc__degree=1, svc__gamma=0.01, svc__kernel=linear;, score=0.747 total time=   0.3s
# [CV 3/3] END svc__C=10, svc__degree=1, svc__gamma=0.01, svc__kernel=linear;, score=0.742 total time=   0.3s
# [CV 1/3] END svc__C=10, svc__degree=1, svc__gamma=0.1, svc__kernel=rbf;, score=0.807 total time=   0.2s
# [CV 2/3] END svc__C=10, svc__degree=1, svc__gamma=0.1, svc__kernel=rbf;, score=0.822 total time=   0.1s
# [CV 3/3] END svc__C=10, svc__degree=1, svc__gamma=0.1, svc__kernel=rbf;, score=0.823 total time=   0.1s
# [CV 1/3] END svc__C=10, svc__degree=1, svc__gamma=0.1, svc__kernel=linear;, score=0.745 total time=   0.3s
# [CV 2/3] END svc__C=10, svc__degree=1, svc__gamma=0.1, svc__kernel=linear;, score=0.747 total time=   0.3s
# [CV 3/3] END svc__C=10, svc__degree=1, svc__gamma=0.1, svc__kernel=linear;, score=0.742 total time=   0.4s
# [CV 1/3] END svc__C=10, svc__degree=1, svc__gamma=1, svc__kernel=rbf;, score=0.797 total time=   0.2s
# [CV 2/3] END svc__C=10, svc__degree=1, svc__gamma=1, svc__kernel=rbf;, score=0.801 total time=   0.2s
# [CV 3/3] END svc__C=10, svc__degree=1, svc__gamma=1, svc__kernel=rbf;, score=0.773 total time=   0.2s
# [CV 1/3] END svc__C=10, svc__degree=1, svc__gamma=1, svc__kernel=linear;, score=0.745 total time=   0.3s
# [CV 2/3] END svc__C=10, svc__degree=1, svc__gamma=1, svc__kernel=linear;, score=0.747 total time=   0.3s
# [CV 3/3] END svc__C=10, svc__degree=1, svc__gamma=1, svc__kernel=linear;, score=0.742 total time=   0.3s
# [CV 1/3] END svc__C=10, svc__degree=2, svc__gamma=0.0001, svc__kernel=rbf;, score=0.746 total time=   0.2s
# [CV 2/3] END svc__C=10, svc__degree=2, svc__gamma=0.0001, svc__kernel=rbf;, score=0.735 total time=   0.2s
# [CV 3/3] END svc__C=10, svc__degree=2, svc__gamma=0.0001, svc__kernel=rbf;, score=0.740 total time=   0.1s
# [CV 1/3] END svc__C=10, svc__degree=2, svc__gamma=0.0001, svc__kernel=linear;, score=0.745 total time=   0.3s
# [CV 2/3] END svc__C=10, svc__degree=2, svc__gamma=0.0001, svc__kernel=linear;, score=0.747 total time=   0.3s
# [CV 3/3] END svc__C=10, svc__degree=2, svc__gamma=0.0001, svc__kernel=linear;, score=0.742 total time=   0.4s
# [CV 1/3] END svc__C=10, svc__degree=2, svc__gamma=0.001, svc__kernel=rbf;, score=0.752 total time=   0.1s
# [CV 2/3] END svc__C=10, svc__degree=2, svc__gamma=0.001, svc__kernel=rbf;, score=0.749 total time=   0.1s
# [CV 3/3] END svc__C=10, svc__degree=2, svc__gamma=0.001, svc__kernel=rbf;, score=0.746 total time=   0.1s
# [CV 1/3] END svc__C=10, svc__degree=2, svc__gamma=0.001, svc__kernel=linear;, score=0.745 total time=   0.3s
# [CV 2/3] END svc__C=10, svc__degree=2, svc__gamma=0.001, svc__kernel=linear;, score=0.747 total time=   0.3s
# [CV 3/3] END svc__C=10, svc__degree=2, svc__gamma=0.001, svc__kernel=linear;, score=0.742 total time=   0.4s
# [CV 1/3] END svc__C=10, svc__degree=2, svc__gamma=0.01, svc__kernel=rbf;, score=0.814 total time=   0.1s
# [CV 2/3] END svc__C=10, svc__degree=2, svc__gamma=0.01, svc__kernel=rbf;, score=0.797 total time=   0.1s
# [CV 3/3] END svc__C=10, svc__degree=2, svc__gamma=0.01, svc__kernel=rbf;, score=0.798 total time=   0.1s
# [CV 1/3] END svc__C=10, svc__degree=2, svc__gamma=0.01, svc__kernel=linear;, score=0.745 total time=   0.3s
# [CV 2/3] END svc__C=10, svc__degree=2, svc__gamma=0.01, svc__kernel=linear;, score=0.747 total time=   0.3s
# [CV 3/3] END svc__C=10, svc__degree=2, svc__gamma=0.01, svc__kernel=linear;, score=0.742 total time=   0.4s
# [CV 1/3] END svc__C=10, svc__degree=2, svc__gamma=0.1, svc__kernel=rbf;, score=0.807 total time=   0.1s
# [CV 2/3] END svc__C=10, svc__degree=2, svc__gamma=0.1, svc__kernel=rbf;, score=0.822 total time=   0.1s
# [CV 3/3] END svc__C=10, svc__degree=2, svc__gamma=0.1, svc__kernel=rbf;, score=0.823 total time=   0.1s
# [CV 1/3] END svc__C=10, svc__degree=2, svc__gamma=0.1, svc__kernel=linear;, score=0.745 total time=   0.3s
# [CV 2/3] END svc__C=10, svc__degree=2, svc__gamma=0.1, svc__kernel=linear;, score=0.747 total time=   0.3s
# [CV 3/3] END svc__C=10, svc__degree=2, svc__gamma=0.1, svc__kernel=linear;, score=0.742 total time=   0.4s
# [CV 1/3] END svc__C=10, svc__degree=2, svc__gamma=1, svc__kernel=rbf;, score=0.797 total time=   0.2s
# [CV 2/3] END svc__C=10, svc__degree=2, svc__gamma=1, svc__kernel=rbf;, score=0.801 total time=   0.2s
# [CV 3/3] END svc__C=10, svc__degree=2, svc__gamma=1, svc__kernel=rbf;, score=0.773 total time=   0.2s
# [CV 1/3] END svc__C=10, svc__degree=2, svc__gamma=1, svc__kernel=linear;, score=0.745 total time=   0.3s
# [CV 2/3] END svc__C=10, svc__degree=2, svc__gamma=1, svc__kernel=linear;, score=0.747 total time=   0.3s
# [CV 3/3] END svc__C=10, svc__degree=2, svc__gamma=1, svc__kernel=linear;, score=0.742 total time=   0.4s
# [CV 1/3] END svc__C=10, svc__degree=3, svc__gamma=0.0001, svc__kernel=rbf;, score=0.746 total time=   0.2s
# [CV 2/3] END svc__C=10, svc__degree=3, svc__gamma=0.0001, svc__kernel=rbf;, score=0.735 total time=   0.2s
# [CV 3/3] END svc__C=10, svc__degree=3, svc__gamma=0.0001, svc__kernel=rbf;, score=0.740 total time=   0.1s
# [CV 1/3] END svc__C=10, svc__degree=3, svc__gamma=0.0001, svc__kernel=linear;, score=0.745 total time=   0.3s
# [CV 2/3] END svc__C=10, svc__degree=3, svc__gamma=0.0001, svc__kernel=linear;, score=0.747 total time=   0.3s
# [CV 3/3] END svc__C=10, svc__degree=3, svc__gamma=0.0001, svc__kernel=linear;, score=0.742 total time=   0.4s
# [CV 1/3] END svc__C=10, svc__degree=3, svc__gamma=0.001, svc__kernel=rbf;, score=0.752 total time=   0.1s
# [CV 2/3] END svc__C=10, svc__degree=3, svc__gamma=0.001, svc__kernel=rbf;, score=0.749 total time=   0.1s
# [CV 3/3] END svc__C=10, svc__degree=3, svc__gamma=0.001, svc__kernel=rbf;, score=0.746 total time=   0.1s
# [CV 1/3] END svc__C=10, svc__degree=3, svc__gamma=0.001, svc__kernel=linear;, score=0.745 total time=   0.3s
# [CV 2/3] END svc__C=10, svc__degree=3, svc__gamma=0.001, svc__kernel=linear;, score=0.747 total time=   0.3s
# [CV 3/3] END svc__C=10, svc__degree=3, svc__gamma=0.001, svc__kernel=linear;, score=0.742 total time=   0.4s
# [CV 1/3] END svc__C=10, svc__degree=3, svc__gamma=0.01, svc__kernel=rbf;, score=0.814 total time=   0.1s
# [CV 2/3] END svc__C=10, svc__degree=3, svc__gamma=0.01, svc__kernel=rbf;, score=0.797 total time=   0.1s
# [CV 3/3] END svc__C=10, svc__degree=3, svc__gamma=0.01, svc__kernel=rbf;, score=0.798 total time=   0.1s
# [CV 1/3] END svc__C=10, svc__degree=3, svc__gamma=0.01, svc__kernel=linear;, score=0.745 total time=   0.3s
# [CV 2/3] END svc__C=10, svc__degree=3, svc__gamma=0.01, svc__kernel=linear;, score=0.747 total time=   0.3s
# [CV 3/3] END svc__C=10, svc__degree=3, svc__gamma=0.01, svc__kernel=linear;, score=0.742 total time=   0.4s
# [CV 1/3] END svc__C=10, svc__degree=3, svc__gamma=0.1, svc__kernel=rbf;, score=0.807 total time=   0.1s
# [CV 2/3] END svc__C=10, svc__degree=3, svc__gamma=0.1, svc__kernel=rbf;, score=0.822 total time=   0.1s
# [CV 3/3] END svc__C=10, svc__degree=3, svc__gamma=0.1, svc__kernel=rbf;, score=0.823 total time=   0.1s
# [CV 1/3] END svc__C=10, svc__degree=3, svc__gamma=0.1, svc__kernel=linear;, score=0.745 total time=   0.3s
# [CV 2/3] END svc__C=10, svc__degree=3, svc__gamma=0.1, svc__kernel=linear;, score=0.747 total time=   0.3s
# [CV 3/3] END svc__C=10, svc__degree=3, svc__gamma=0.1, svc__kernel=linear;, score=0.742 total time=   0.4s
# [CV 1/3] END svc__C=10, svc__degree=3, svc__gamma=1, svc__kernel=rbf;, score=0.797 total time=   0.2s
# [CV 2/3] END svc__C=10, svc__degree=3, svc__gamma=1, svc__kernel=rbf;, score=0.801 total time=   0.2s
# [CV 3/3] END svc__C=10, svc__degree=3, svc__gamma=1, svc__kernel=rbf;, score=0.773 total time=   0.2s
# [CV 1/3] END svc__C=10, svc__degree=3, svc__gamma=1, svc__kernel=linear;, score=0.745 total time=   0.3s
# [CV 2/3] END svc__C=10, svc__degree=3, svc__gamma=1, svc__kernel=linear;, score=0.747 total time=   0.3s
# [CV 3/3] END svc__C=10, svc__degree=3, svc__gamma=1, svc__kernel=linear;, score=0.742 total time=   0.4s
# From the tuned SVC StandardScaler the average roc_auc is 0.834

# %%
##GradientBoostingClassifier
gbc_model = GradientBoostingClassifier(learning_rate=0.01,
                                       max_depth=50,
                                       subsample=0.9,
                                       n_estimators = 1000,
                                       loss = 'exponential',
                                       n_iter_no_change = 10)
model = gbc_model.fit(X_test, y_test)
gbc_model_scores = cross_val_score(model, X_test, y_test, scoring='roc_auc', cv=5)
print('From the Gradient Boosting Classfier the average roc_auc score is {0}'.format(str(round(mean(gbc_model_scores), 4))))
# Out:
# From the Gradient Boosting Classfier the average roc_auc score is 0.8687

# %%
## Results
models = ['Logistic Regression', 'Not tuned StandardScaler', 'StandardScaler tuned with Grid Search', 'Gradient Boosting Classifier']
scores = [logres_model_scores, svc_model_scores, gs_scv_model_scores, gbc_model_scores]

for i in range(0,4):
  print('From the model {0} the average auc_score from a 5-folded cross valudation is {1}'.format(models[i], str(round(mean(scores[i]),3))))
# Out:
# From the model Logistic Regression the average auc_score from a 5-folded cross valudation is 0.744
# From the model Not tuned StandardScaler the average auc_score from a 5-folded cross valudation is 0.832
# From the model StandardScaler tuned with Grid Search the average auc_score from a 5-folded cross valudation is 0.834
# From the model Gradient Boosting Classifier the average auc_score from a 5-folded cross valudation is 0.869
